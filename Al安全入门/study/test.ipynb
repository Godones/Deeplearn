# %%
import numpy as np
import torch
import os
import torch.nn
import torchvision.models as models
import torch.cuda
from torchvision.transforms import transforms
from PIL import Image
import cv2

# %%
resnet = models.resnet50(pretrained=True).eval()
img = Image.open("hashiqi.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=366x245 at 0x291FFF4E4C8>

# %%
show_imag = cv2.cvtColor(img,COLOR_BGR2RGB)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5c5a28e39150> in <module>
# ----> 1 show_imag = cv2.cvtColor(img,COLOR_BGR2RGB)
#       2
#
# NameError: name 'COLOR_BGR2RGB' is not defined

# %%
img = img.resize((224,224))

# %%
img = np.array(img).copy().astype(np.float32)
img.shape

# %%
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]
img /= 255.0
img = (img - mean)/std
img = img.transpose(2, 0, 1)
img=np.expand_dims(img, axis=0)
img = torch.tensor(img,dtype=torch.float32)

# %%
# img = img.to(torch.double)
img

# %%
label=np.argmax(resnet(img).data.cpu().numpy())
print("label={}".format(label))
